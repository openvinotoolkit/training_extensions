# %% [markdown]
# # OTX CLI Usage
#
# ### Requirements
# - R1. For Lite-CLI users, a tutorial should be provided on how the behavior is possible. the following steps should be clearly presented.
# - R2. It should be clear to the CLI user what values are being run with, and the user should be able to verify it.
# - R3. For All CLI users should be able to easily use the configuration provided by OTX. And overriding via commands should be possible.
# - R4. Advanced-Level CLI users should be able to get all the information about what values are available for overriding.

# %% [markdown]
# R1. For Lite-CLI users, a tutorial should be provided on how the behavior is possible. the following steps should be clearly presented.

# %%
# !otx --help
# Out:
# ╭─ Arguments ──────────────────────────────────────────────────────────────────╮
# │ Usage: otx [-h] [-v] {install,train,test,predict,export} ...                 │
# │                                                                              │
# │                                                                              │
# │ OpenVINO Training-Extension command line tool                                │
# │                                                                              │
# │                                                                              │
# │ Options:                                                                     │
# │   -h, --help            Show this help message and exit.                     │
# │   -v, --version         Display OTX version number.                          │
# │                                                                              │
# │ Subcommands:                                                                 │
# ...

# %%
# !otx train --help
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                   OpenVINO™ Training Extensions CLI Guide                    ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Github Repository: ]8;id=137110;https://github.com/openvinotoolkit/training_extensions\https://github.com/openvinotoolkit/training_extensions]8;;\.
#
# A better guide is provided by the ]8;id=417836;https://openvinotoolkit.github.io/training_extensions/stable/\documentation]8;;\.
# ╭─ Quick-Start ────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │  1 you can pick a model, and you can run through the dataset.                │
# │                                                                              │
# │                                                                              │
# ...

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace -h -v
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃                   OpenVINO™ Training Extensions CLI Guide                    ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┛
#
# Github Repository: ]8;id=644270;https://github.com/openvinotoolkit/training_extensions\https://github.com/openvinotoolkit/training_extensions]8;;\.
#
# A better guide is provided by the ]8;id=625682;https://openvinotoolkit.github.io/training_extensions/stable/\documentation]8;;\.
# ╭─ Quick-Start ────────────────────────────────────────────────────────────────╮
# │                                                                              │
# │  1 you can pick a model, and you can run through the dataset.                │
# │                                                                              │
# │                                                                              │
# ...

# %% [markdown]
# R2. It should be clear to the CLI user what values are being run with, and the user should be able to verify it.

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace --max_epochs 3 --print_config
# Out:
# data_root: ../../tests/assets/classification_dataset
# engine:
#   task: MULTI_CLASS_CLS
#   work_dir: ./otx-workspace
#   device: auto
# model:
#   class_path: otx.core.model.module.classification.OTXClassificationLitModule
#   init_args:
#     otx_model:
#       class_path: otx.core.model.entity.classification.MMPretrainCompatibleModel
#       init_args:
#         config:
#           backbone:
#             version: b0
#             pretrained: true
#             type: OTXEfficientNet
#           head:
#             act_cfg:
#               type: HSwish
#             dropout_rate: 0.2
#             in_channels: 1280
#             init_cfg:
#               bias: 0.0
#               layer: Linear
#               mean: 0.0
#               std: 0.01
#               type: Normal
#             loss:
#               loss_weight: 1.0
#               type: CrossEntropyLoss
#             mid_channels:
#             - 1280
#             num_classes: 1000
#             topk:
#             - 1
# ...

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace --max_epochs 3
# Out:
#
#
#                            ██████╗  ████████╗ ██╗  ██╗
#                           ██╔═══██╗ ╚══██╔══╝ ╚██╗██╔╝
#                           ██║   ██║    ██║     ╚███╔╝
#                           ██║   ██║    ██║     ██╔██╗
#                           ╚██████╔╝    ██║    ██╔╝ ██╗
#                            ╚═════╝     ╚═╝    ╚═╝  ╚═╝
#
#                                     ver.2.0.0
# init weight - https://github.com/osmr/imgclsmob/releases/download/v0.0.364/efficientnet_b0-0752-0e386130.pth.zip
# 01/03 15:19:06 - mmengine - INFO -
# backbone.features.init_block.conv.conv.weight - torch.Size([32, 3, 3, 3]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:19:06 - mmengine - INFO -
# backbone.features.init_block.conv.bn.weight - torch.Size([32]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:19:06 - mmengine - INFO -
# backbone.features.init_block.conv.bn.bias - torch.Size([32]):
# ...

# %% [markdown]
# R3. For All CLI users should be able to easily use the configuration provided by OTX. And overriding via commands should be possible.

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace --max_epochs 3 --print_config > test_config.yaml

# %%
# !otx train --config ./test_config.yaml
# Out:
#
#
#                            ██████╗  ████████╗ ██╗  ██╗
#                           ██╔═══██╗ ╚══██╔══╝ ╚██╗██╔╝
#                           ██║   ██║    ██║     ╚███╔╝
#                           ██║   ██║    ██║     ██╔██╗
#                           ╚██████╔╝    ██║    ██╔╝ ██╗
#                            ╚═════╝     ╚═╝    ╚═╝  ╚═╝
#
#                                     ver.2.0.0
# init weight - https://github.com/osmr/imgclsmob/releases/download/v0.0.364/efficientnet_b0-0752-0e386130.pth.zip
# 01/03 15:19:52 - mmengine - INFO -
# backbone.features.init_block.conv.conv.weight - torch.Size([32, 3, 3, 3]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:19:52 - mmengine - INFO -
# backbone.features.init_block.conv.bn.weight - torch.Size([32]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:19:52 - mmengine - INFO -
# backbone.features.init_block.conv.bn.bias - torch.Size([32]):
# ...

# %% [markdown]
# R4. Advanced-Level CLI users should be able to get all the information about what values are available for overriding.

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace -h -vv
# Out:
# ╭─ Arguments ──────────────────────────────────────────────────────────────────╮
# │ Usage: otx [options] train [-h] [-v] [-c CONFIG] [--print_config [=flags]]   │
# │                            [--data_root DATA_ROOT] [--engine CONFIG]         │
# │                            [--engine.task {MULTI_CLASS_CLS,DETECTION,INSTANC │
# │                            [--engine.work_dir WORK_DIR]                      │
# │                            [data_root --> engine.data_root [applied on parse │
# │                            [--engine.device {auto,gpu,cpu,tpu,ipu,hpu,mps}]  │
# │                            [--model.help CLASS_PATH_OR_NAME]                 │
# │                            [--model CONFIG | CLASS_PATH_OR_NAME | .INIT_ARG_ │
# │                            [--data CONFIG]                                   │
# │                            [--data.task {MULTI_CLASS_CLS,DETECTION,INSTANCE_ │
# │                            [--data.config CONFIG]                            │
# ...

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace --data.config.train_subset.batch_size 2 --max_epochs 5 --print_config
# Out:
# data_root: ../../tests/assets/classification_dataset
# engine:
#   task: MULTI_CLASS_CLS
#   work_dir: ./otx-workspace
#   device: auto
# model:
#   class_path: otx.core.model.module.classification.OTXClassificationLitModule
#   init_args:
#     otx_model:
#       class_path: otx.core.model.entity.classification.MMPretrainCompatibleModel
#       init_args:
#         config:
#           backbone:
#             version: b0
#             pretrained: true
#             type: OTXEfficientNet
#           head:
#             act_cfg:
#               type: HSwish
#             dropout_rate: 0.2
#             in_channels: 1280
#             init_cfg:
#               bias: 0.0
#               layer: Linear
#               mean: 0.0
#               std: 0.01
#               type: Normal
#             loss:
#               loss_weight: 1.0
#               type: CrossEntropyLoss
#             mid_channels:
#             - 1280
#             num_classes: 1000
#             topk:
#             - 1
# ...

# %%
# !otx train --data_root ../../tests/assets/classification_dataset --engine.work_dir ./otx-workspace --data.config.train_subset.batch_size 2 --max_epochs 5
# Out:
#
#
#                            ██████╗  ████████╗ ██╗  ██╗
#                           ██╔═══██╗ ╚══██╔══╝ ╚██╗██╔╝
#                           ██║   ██║    ██║     ╚███╔╝
#                           ██║   ██║    ██║     ██╔██╗
#                           ╚██████╔╝    ██║    ██╔╝ ██╗
#                            ╚═════╝     ╚═╝    ╚═╝  ╚═╝
#
#                                     ver.2.0.0
# init weight - https://github.com/osmr/imgclsmob/releases/download/v0.0.364/efficientnet_b0-0752-0e386130.pth.zip
# 01/03 15:20:12 - mmengine - INFO -
# backbone.features.init_block.conv.conv.weight - torch.Size([32, 3, 3, 3]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:20:12 - mmengine - INFO -
# backbone.features.init_block.conv.bn.weight - torch.Size([32]):
# The value is the same before and after calling `init_weights` of ImageClassifier
#
# 01/03 15:20:12 - mmengine - INFO -
# backbone.features.init_block.conv.bn.bias - torch.Size([32]):
# ...
